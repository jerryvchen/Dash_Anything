# %% [markdown]
# # Test
# Cumulative code from parts 1-3

# %%
import cv2
from PIL import Image
import torch
from torchvision.models import resnet50, ResNet50_Weights
from collections import deque
import numpy as np
import matplotlib as plt
import win32gui
import win32api
import win32con
import time
import gymnasium
from gymnasium import spaces
from stable_baselines3 import DQN

VIDEO_IDX = 1 # OBS virtual cam index

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
class ResNetEmbeddings:
    def __init__(self) -> None:
        # get model weight 
        self._weights = ResNet50_Weights.DEFAULT
        self._preprocess = self._weights.transforms()

        # get model
        self._model = resnet50(weights=self._weights).to(device)
        self._model.eval()

        self._feature_extractor = torch.nn.Sequential(*(list(self._model.children())[:-1])).to(device)
    
    def get_img_embedding(self, img):
        img_transformed = self._preprocess(img).unsqueeze(0).to(device)

        with torch.no_grad():
            embedding = self._feature_extractor(img_transformed).squeeze().cpu()
        return embedding

# %%
class FrameStacker:
    def __init__(self, stack_size=4, embedding_dim=2048):
        self.stack_size = stack_size
        self.embedding_dim = embedding_dim
        self.stack = deque(maxlen=stack_size)  # Fixed-size buffer

    def reset_stack(self, initial_embedding):
        self.stack.clear()
        for _ in range(self.stack_size): # fill with copies of first frame
            self.stack.append(initial_embedding)
        return self._get_stacked_embeddings()

    def add_frame(self, embedding):
        self.stack.append(embedding)
        return self._get_stacked_embeddings() # also returns current stacked embedings

    def _get_stacked_embeddings(self):
        return np.concatenate(self.stack, axis=0)

# %%
class EventDetectorWithROI:
    def __init__(
            self, 
            completion_template_path = "./template_img/complete_template.png",
            retry_template_path = "./template_img/retry_template.png", 
            completion_roi = (120, 110, 400, 40), 
            retry_roi = (160, 375, 55, 50) 
            ):
        # templates
        self.completion_template = cv2.imread(completion_template_path, cv2.IMREAD_GRAYSCALE)
        self.retry_template = cv2.imread(retry_template_path, cv2.IMREAD_GRAYSCALE)

        # roi regions
        self.retry_roi = retry_roi
        self.completion_roi = completion_roi
        print(self.completion_template.shape)
        print(self.retry_template.shape)

    def _crop_to_roi(self, frame, roi):
        """
        Crop the frame to the given ROI.
        """
        x, y, w, h = roi
        return frame[y:y+h, x:x+w]

    def detect_event(self, frame):
        """
        Detect if the player has died or completed the level.
        
        returns tring "death", "completion", or None
        """
        if isinstance(frame, Image.Image):
            frame = np.array(frame)
        # Convert the frame to grayscale
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Crop the ROIs
        retry_roi_frame = self._crop_to_roi(gray_frame, self.retry_roi)
        completion_roi_frame = self._crop_to_roi(gray_frame, self.completion_roi)

        # Detect completion (Completion screen)
        completion_res = cv2.matchTemplate(completion_roi_frame, self.completion_template, cv2.TM_CCOEFF_NORMED)
        completion_threshold = 0.9
        if (completion_res >= completion_threshold).any():
            return "completion"
        
        # Detect death (Retry button), also after completion
        retry_res = cv2.matchTemplate(retry_roi_frame, self.retry_template, cv2.TM_CCOEFF_NORMED)
        retry_threshold = 0.8
        if (retry_res >= retry_threshold).any():
            return "death"

        # Detect completion (Completion screen)
        completion_res = cv2.matchTemplate(completion_roi_frame, self.completion_template, cv2.TM_CCOEFF_NORMED)
        completion_threshold = 0.8
        if (completion_res >= completion_threshold).any():
            return "completion"

        return None

# %%
class InputController:
    """
    Handles inputs to Geometry Dash using PyWin32
    """
    def __init__(self, window_name="Geometry Dash"):
        self.window_name = window_name
        self.hwnd = self.get_gd_hwnd()

    def get_gd_hwnd(self):
        hwnd = win32gui.FindWindow(None, self.window_name)
        if hwnd == 0:
            raise RuntimeError("Geometry Dash window not found. Make sure the game is running.")
        # print(f"Found Geometry Dash window: {hwnd}")
        return hwnd

    def send_keydown(self, key = None):
        """
        Send a KeyDown (Spacebar pressed) message to Geometry Dash.
        """
        if self.hwnd:
            if key:
                win32api.PostMessage(self.hwnd, win32con.WM_KEYDOWN, ord(key), 0)
            else:
                win32api.PostMessage(self.hwnd, win32con.WM_KEYDOWN, win32con.VK_SPACE, 0)

    def send_keyup(self, key = None):
        """
        Send a KeyUp (Spacebar released) message to Geometry Dash.
        """
        if self.hwnd:
            if key:
                win32api.PostMessage(self.hwnd, win32con.WM_KEYUP, ord(key), 0xC0000000)
            else:
                win32api.PostMessage(self.hwnd, win32con.WM_KEYUP, win32con.VK_SPACE, 0xC0000000)

    def reset_game(self):
        """
        Simulate resetting the Geometry Dash game (press 'R').
        """
        time.sleep(0.5)
        if self.hwnd:
            # Send 'r' key press to reset
            self.send_keydown('r')
            time.sleep(0.05)  # Short delay
            self.send_keyup('r')
            # print("Reset command sent to Geometry Dash!")
            self.send_keydown()
            time.sleep(0.05)  # Short delay
            self.send_keyup()

# %%
class GeometryDashEnv(gymnasium.Env):
    def __init__(self, frame_stacker, resnet_extractor, input_controller, event_detector, video_idx=VIDEO_IDX):
        super(GeometryDashEnv, self).__init__()
        print("Environment initialized!")

        # Initialize components
        self.frame_stacker: FrameStacker = frame_stacker
        self.resnet_extractor: ResNetEmbeddings = resnet_extractor
        self.input_controller: InputController = input_controller
        self.event_detector: EventDetectorWithROI = event_detector

        # Open the camera (OBS virtual camera)
        self.cap = cv2.VideoCapture(video_idx)
        if not self.cap.isOpened():
            raise RuntimeError(f"Failed to open video capture device at index {video_idx}.")

        # Define action and observation spaces
        self.observation_space = spaces.Box(
            low=-np.inf,
            high=np.inf,
            shape=(2048 * frame_stacker.stack_size,),
            dtype=np.float32
        )
        self.action_space = spaces.Discrete(2)  # 0: KeyUp, 1: KeyDown

        # Environment state
        self.current_state = None
        self.done = True
        self.previous_action = None

    def reset(self, *, seed=None, options=None):
        """
        Reset the environment and return the initial observation.
        """
        # Reset the game
        self.input_controller.reset_game()

        # Capture the first frame and process
        frame = self._capture_frame()
        initial_embedding = self.resnet_extractor.get_img_embedding(frame)

        # Initialize the frame stack
        self.current_state = self.frame_stacker.reset_stack(initial_embedding)
        self.done = False
        self.previous_action = None

        # gymnaisium stuff
        if seed is not None:
            self.np_random, seed = gymnasium.utils.seeding.np_random(seed)

        return self.current_state, {}

    def step(self, action):
        """
        Perform an action and return observation, reward, done, and info.
        """
        # Send the action to the game
        if action != self.previous_action:
            if action == 0:
                self.input_controller.send_keyup()
            else:
                self.input_controller.send_keydown()
            self.previous_action = action

        # Capture the next frame and process
        frame = self._capture_frame()
        next_embedding = self.resnet_extractor.get_img_embedding(frame)
        self.current_state = self.frame_stacker.add_frame(next_embedding)

        # Detect events (death or completion)
        event = self.event_detector.detect_event(frame)
        self.done = event in ["death", "completion"]

        # Calculate the reward
        reward = self._calculate_reward(event)

        return self.current_state, reward, self.done, False, {}

    def _capture_frame(self):
        """
        Capture a frame from the camera.
        """
        while True:
            ret, frame = self.cap.read()
            if ret:
                break
            else:
                print('fk')
        
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        pil_frame = Image.fromarray(frame)
        return pil_frame

    def _calculate_reward(self, event):
        """
        Calculate the reward based on the current event.
        """
        if event == "death":
            return -100  # Penalty for death
        elif event == "completion":
            return 500  # Reward for completing the level
        else:
            return 2e-2  # Survival reward (training on 0.2)

    def close(self):
        """
        Release the camera and perform cleanup.
        """
        if self.cap.isOpened():
            self.cap.release()
        cv2.destroyAllWindows()

# %%
frame_stacker = FrameStacker(stack_size=4, embedding_dim=2048)
resnet_extractor = ResNetEmbeddings()
input_controller = InputController(window_name="Geometry Dash")
event_detector = EventDetectorWithROI(
    "./template_img/complete_template.png",
    "./template_img/retry_template.png",
    completion_roi=(120, 110, 400, 40), 
    retry_roi=(160, 375, 55, 50) 
)
# Out:
# (40, 400)
# (50, 55)

# %%
# make env
env = GeometryDashEnv(
    frame_stacker, 
    resnet_extractor, 
    input_controller, 
    event_detector
)
# Out:
# Environment initialized!

# %%
# test env
obs, info = env.reset()
for _ in range(100):
    action = env.action_space.sample()
    obs, reward, done, truncated, info = env.step(action)
    print(f"Action: {action}, Reward: {reward}, Done: {done}, Truncated: {truncated}")
    if done or truncated:
        obs, info = env.reset()
env.close()

# %%
model = DQN(
    policy='MlpPolicy',
    env = env,
    buffer_size=10_000,
    batch_size=16,
    verbose=1,
    tensorboard_log='./dqn_gd_tensorboard'
)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1_000_000)
model.save('dqn_geometry_dash')
# Out:
# Logging to ./dqn_gd_tensorboard\DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.19e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 29       |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 4744     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.22e-05 |
# |    n_updates        | 1160     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.25e+03 |
# |    ep_rew_mean      | 350      |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 29       |
# |    time_elapsed     | 605      |
# |    total_timesteps  | 17998    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.35e-05 |
# |    n_updates        | 4474     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.66e+03 |
# |    ep_rew_mean      | 432      |
# |    exploration_rate | 0.697    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 29       |
# |    time_elapsed     | 1072     |
# |    total_timesteps  | 31925    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.35e-05 |
# |    n_updates        | 7956     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.42e+03 |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 29       |
# |    time_elapsed     | 1300     |
# |    total_timesteps  | 38706    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.54e-05 |
# |    n_updates        | 9651     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 302      |
# |    exploration_rate | 0.618    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 29       |
# |    time_elapsed     | 1352     |
# |    total_timesteps  | 40199    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000201 |
# |    n_updates        | 10024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.41e+03 |
# |    ep_rew_mean      | 381      |
# |    exploration_rate | 0.451    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 29       |
# |    time_elapsed     | 1941     |
# |    total_timesteps  | 57780    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000146 |
# |    n_updates        | 14419    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.25e+03 |
# |    ep_rew_mean      | 350      |
# |    exploration_rate | 0.402    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 29       |
# |    time_elapsed     | 2116     |
# |    total_timesteps  | 62967    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000319 |
# |    n_updates        | 15716    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 311      |
# |    exploration_rate | 0.374    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 29       |
# |    time_elapsed     | 2215     |
# |    total_timesteps  | 65850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000912 |
# |    n_updates        | 16437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 287      |
# |    exploration_rate | 0.337    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 29       |
# |    time_elapsed     | 2347     |
# |    total_timesteps  | 69749    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.06e-05 |
# |    n_updates        | 17412    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.91e+03 |
# |    ep_rew_mean      | 283      |
# |    exploration_rate | 0.273    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 29       |
# |    time_elapsed     | 2577     |
# |    total_timesteps  | 76563    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000143 |
# |    n_updates        | 19115    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.78e+03 |
# |    ep_rew_mean      | 255      |
# |    exploration_rate | 0.257    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 29       |
# |    time_elapsed     | 2635     |
# |    total_timesteps  | 78238    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000363 |
# |    n_updates        | 19534    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.73e+03 |
# |    ep_rew_mean      | 246      |
# |    exploration_rate | 0.211    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 29       |
# |    time_elapsed     | 2797     |
# |    total_timesteps  | 83032    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.17e-05 |
# |    n_updates        | 20732    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.67e+03 |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.177    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 29       |
# |    time_elapsed     | 2919     |
# |    total_timesteps  | 86610    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000238 |
# |    n_updates        | 21627    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.61e+03 |
# |    ep_rew_mean      | 221      |
# |    exploration_rate | 0.145    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 29       |
# |    time_elapsed     | 3036     |
# |    total_timesteps  | 90046    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00269  |
# |    n_updates        | 22486    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.52e+03 |
# |    ep_rew_mean      | 203      |
# |    exploration_rate | 0.135    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 29       |
# |    time_elapsed     | 3070     |
# |    total_timesteps  | 91002    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00224  |
# |    n_updates        | 22725    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.47e+03 |
# |    ep_rew_mean      | 195      |
# |    exploration_rate | 0.104    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 29       |
# |    time_elapsed     | 3183     |
# |    total_timesteps  | 94337    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0101   |
# |    n_updates        | 23559    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.42e+03 |
# |    ep_rew_mean      | 184      |
# |    exploration_rate | 0.0811   |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 29       |
# |    time_elapsed     | 3265     |
# |    total_timesteps  | 96722    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000134 |
# |    n_updates        | 24155    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.35e+03 |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.076    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 29       |
# |    time_elapsed     | 3286     |
# |    total_timesteps  | 97260    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000234 |
# |    n_updates        | 24289    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.3e+03  |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.0591   |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 29       |
# |    time_elapsed     | 3347     |
# |    total_timesteps  | 99037    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.83e-05 |
# |    n_updates        | 24734    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.25e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.0508   |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 29       |
# |    time_elapsed     | 3379     |
# |    total_timesteps  | 99911    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.29     |
# |    n_updates        | 24952    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.2e+03  |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 29       |
# |    time_elapsed     | 3408     |
# |    total_timesteps  | 100711   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000309 |
# |    n_updates        | 25152    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.16e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 29       |
# |    time_elapsed     | 3459     |
# |    total_timesteps  | 102163   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000428 |
# |    n_updates        | 25515    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.12e+03 |
# |    ep_rew_mean      | 124      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 29       |
# |    time_elapsed     | 3490     |
# |    total_timesteps  | 103014   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000166 |
# |    n_updates        | 25728    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.09e+03 |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 29       |
# |    time_elapsed     | 3531     |
# |    total_timesteps  | 104188   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000211 |
# |    n_updates        | 26021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.05e+03 |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 29       |
# |    time_elapsed     | 3556     |
# |    total_timesteps  | 104876   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00795  |
# |    n_updates        | 26193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02e+03 |
# |    ep_rew_mean      | 103      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 29       |
# |    time_elapsed     | 3606     |
# |    total_timesteps  | 106280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.26     |
# |    n_updates        | 26544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 902      |
# |    ep_rew_mean      | 80.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 29       |
# |    time_elapsed     | 3671     |
# |    total_timesteps  | 108171   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 27017    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 780      |
# |    ep_rew_mean      | 55.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 29       |
# |    time_elapsed     | 3731     |
# |    total_timesteps  | 109897   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000294 |
# |    n_updates        | 27449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 717      |
# |    ep_rew_mean      | 43.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 29       |
# |    time_elapsed     | 3752     |
# |    total_timesteps  | 110450   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00593  |
# |    n_updates        | 27587    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 713      |
# |    ep_rew_mean      | 42.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 29       |
# |    time_elapsed     | 3789     |
# |    total_timesteps  | 111486   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00104  |
# |    n_updates        | 27846    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 561      |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 29       |
# |    time_elapsed     | 3871     |
# |    total_timesteps  | 113891   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000189 |
# |    n_updates        | 28447    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 516      |
# |    ep_rew_mean      | 3.02     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 29       |
# |    time_elapsed     | 3897     |
# |    total_timesteps  | 114577   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000134 |
# |    n_updates        | 28619    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 500      |
# |    ep_rew_mean      | -0.214   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 29       |
# |    time_elapsed     | 3941     |
# |    total_timesteps  | 115843   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000661 |
# |    n_updates        | 28935    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | -7.48    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 29       |
# |    time_elapsed     | 3952     |
# |    total_timesteps  | 116111   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000561 |
# |    n_updates        | 29002    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 416      |
# |    ep_rew_mean      | -16.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 29       |
# |    time_elapsed     | 4024     |
# |    total_timesteps  | 118188   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000736 |
# |    n_updates        | 29521    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 402      |
# |    ep_rew_mean      | -19.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 29       |
# |    time_elapsed     | 4034     |
# |    total_timesteps  | 118405   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00033  |
# |    n_updates        | 29576    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 357      |
# |    ep_rew_mean      | -28.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 29       |
# |    time_elapsed     | 4048     |
# |    total_timesteps  | 118775   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00379  |
# |    n_updates        | 29668    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 325      |
# |    ep_rew_mean      | -35.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 29       |
# |    time_elapsed     | 4062     |
# |    total_timesteps  | 119098   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000181 |
# |    n_updates        | 29749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 295      |
# |    ep_rew_mean      | -41.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 29       |
# |    time_elapsed     | 4079     |
# |    total_timesteps  | 119535   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0017   |
# |    n_updates        | 29858    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 292      |
# |    ep_rew_mean      | -41.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 29       |
# |    time_elapsed     | 4102     |
# |    total_timesteps  | 120169   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.19     |
# |    n_updates        | 30017    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 272      |
# |    ep_rew_mean      | -45.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 29       |
# |    time_elapsed     | 4149     |
# |    total_timesteps  | 121495   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00117  |
# |    n_updates        | 30348    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 259      |
# |    ep_rew_mean      | -48.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 29       |
# |    time_elapsed     | 4189     |
# |    total_timesteps  | 122636   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000282 |
# |    n_updates        | 30633    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 259      |
# |    ep_rew_mean      | -48.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 29       |
# |    time_elapsed     | 4209     |
# |    total_timesteps  | 123162   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0025   |
# |    n_updates        | 30765    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 250      |
# |    ep_rew_mean      | -50.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 29       |
# |    time_elapsed     | 4242     |
# |    total_timesteps  | 124075   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.74e-05 |
# |    n_updates        | 30993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 248      |
# |    ep_rew_mean      | -50.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 29       |
# |    time_elapsed     | 4267     |
# |    total_timesteps  | 124747   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000174 |
# |    n_updates        | 31161    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 244      |
# |    ep_rew_mean      | -51.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 29       |
# |    time_elapsed     | 4281     |
# |    total_timesteps  | 125102   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000274 |
# |    n_updates        | 31250    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 233      |
# |    ep_rew_mean      | -53.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 29       |
# |    time_elapsed     | 4294     |
# |    total_timesteps  | 125429   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00509  |
# |    n_updates        | 31332    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 229      |
# |    ep_rew_mean      | -54.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 29       |
# |    time_elapsed     | 4313     |
# |    total_timesteps  | 125919   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000437 |
# |    n_updates        | 31454    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 226      |
# |    ep_rew_mean      | -55      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 29       |
# |    time_elapsed     | 4344     |
# |    total_timesteps  | 126764   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.11     |
# |    n_updates        | 31665    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | -55.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 29       |
# |    time_elapsed     | 4355     |
# |    total_timesteps  | 127048   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000275 |
# |    n_updates        | 31736    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 210      |
# |    ep_rew_mean      | -58.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 29       |
# |    time_elapsed     | 4367     |
# |    total_timesteps  | 127316   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00048  |
# |    n_updates        | 31803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | -61.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 29       |
# |    time_elapsed     | 4378     |
# |    total_timesteps  | 127567   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000287 |
# |    n_updates        | 31866    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | -62.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 29       |
# |    time_elapsed     | 4412     |
# |    total_timesteps  | 128527   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.11     |
# |    n_updates        | 32106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | -63.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 29       |
# |    time_elapsed     | 4427     |
# |    total_timesteps  | 128904   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.14     |
# |    n_updates        | 32200    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | -64.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 29       |
# |    time_elapsed     | 4442     |
# |    total_timesteps  | 129294   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000195 |
# |    n_updates        | 32298    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | -69      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 29       |
# |    time_elapsed     | 4452     |
# |    total_timesteps  | 129508   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00143  |
# |    n_updates        | 32351    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 157      |
# |    ep_rew_mean      | -68.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 29       |
# |    time_elapsed     | 4480     |
# |    total_timesteps  | 130292   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000753 |
# |    n_updates        | 32547    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 146      |
# |    ep_rew_mean      | -71.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 29       |
# |    time_elapsed     | 4486     |
# |    total_timesteps  | 130398   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000363 |
# |    n_updates        | 32574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 143      |
# |    ep_rew_mean      | -71.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 29       |
# |    time_elapsed     | 4491     |
# |    total_timesteps  | 130458   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00154  |
# |    n_updates        | 32589    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | -75.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 29       |
# |    time_elapsed     | 4502     |
# |    total_timesteps  | 130733   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00212  |
# |    n_updates        | 32658    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | -75.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 29       |
# |    time_elapsed     | 4511     |
# |    total_timesteps  | 130910   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000394 |
# |    n_updates        | 32702    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 127      |
# |    ep_rew_mean      | -74.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 29       |
# |    time_elapsed     | 4532     |
# |    total_timesteps  | 131489   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000539 |
# |    n_updates        | 32847    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 128      |
# |    ep_rew_mean      | -74.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 28       |
# |    time_elapsed     | 4547     |
# |    total_timesteps  | 131858   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00106  |
# |    n_updates        | 32939    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | -75      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 28       |
# |    time_elapsed     | 4559     |
# |    total_timesteps  | 132156   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00214  |
# |    n_updates        | 33013    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 123      |
# |    ep_rew_mean      | -75.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 28       |
# |    time_elapsed     | 4573     |
# |    total_timesteps  | 132504   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000207 |
# |    n_updates        | 33100    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -76.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 28       |
# |    time_elapsed     | 4602     |
# |    total_timesteps  | 133294   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0002   |
# |    n_updates        | 33298    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -78.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 28       |
# |    time_elapsed     | 4614     |
# |    total_timesteps  | 133576   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000304 |
# |    n_updates        | 33368    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | -78.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 28       |
# |    time_elapsed     | 4626     |
# |    total_timesteps  | 133882   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000821 |
# |    n_updates        | 33445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -78.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 28       |
# |    time_elapsed     | 4664     |
# |    total_timesteps  | 134944   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000371 |
# |    n_updates        | 33710    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | -78.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 28       |
# |    time_elapsed     | 4687     |
# |    total_timesteps  | 135551   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.93     |
# |    n_updates        | 33862    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | -76.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 28       |
# |    time_elapsed     | 4732     |
# |    total_timesteps  | 136835   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00113  |
# |    n_updates        | 34183    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 122      |
# |    ep_rew_mean      | -75.8    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 28       |
# |    time_elapsed     | 4761     |
# |    total_timesteps  | 137622   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000258 |
# |    n_updates        | 34380    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 123      |
# |    ep_rew_mean      | -75.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 28       |
# |    time_elapsed     | 4782     |
# |    total_timesteps  | 138183   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000934 |
# |    n_updates        | 34520    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -76.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 28       |
# |    time_elapsed     | 4798     |
# |    total_timesteps  | 138607   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000328 |
# |    n_updates        | 34626    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 119      |
# |    ep_rew_mean      | -76.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 28       |
# |    time_elapsed     | 4811     |
# |    total_timesteps  | 138926   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00124  |
# |    n_updates        | 34706    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 119      |
# |    ep_rew_mean      | -76.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 28       |
# |    time_elapsed     | 4823     |
# |    total_timesteps  | 139205   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000721 |
# |    n_updates        | 34776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | -73.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 28       |
# |    time_elapsed     | 4884     |
# |    total_timesteps  | 140961   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0575   |
# |    n_updates        | 35215    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 131      |
# |    ep_rew_mean      | -74      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 28       |
# |    time_elapsed     | 4908     |
# |    total_timesteps  | 141610   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000433 |
# |    n_updates        | 35377    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 132      |
# |    ep_rew_mean      | -73.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 28       |
# |    time_elapsed     | 4926     |
# |    total_timesteps  | 142076   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000345 |
# |    n_updates        | 35493    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | -73.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 28       |
# |    time_elapsed     | 4951     |
# |    total_timesteps  | 142752   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00063  |
# |    n_updates        | 35662    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 146      |
# |    ep_rew_mean      | -71      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 28       |
# |    time_elapsed     | 4999     |
# |    total_timesteps  | 144131   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000561 |
# |    n_updates        | 36007    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 149      |
# |    ep_rew_mean      | -70.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 28       |
# |    time_elapsed     | 5036     |
# |    total_timesteps  | 145151   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00964  |
# |    n_updates        | 36262    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 168      |
# |    ep_rew_mean      | -66.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 28       |
# |    time_elapsed     | 5107     |
# |    total_timesteps  | 147230   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0419   |
# |    n_updates        | 36782    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | -59.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 28       |
# |    time_elapsed     | 5225     |
# |    total_timesteps  | 150692   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000707 |
# |    n_updates        | 37647    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 207      |
# |    ep_rew_mean      | -58.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 28       |
# |    time_elapsed     | 5251     |
# |    total_timesteps  | 151408   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000208 |
# |    n_updates        | 37826    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 208      |
# |    ep_rew_mean      | -58.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 28       |
# |    time_elapsed     | 5264     |
# |    total_timesteps  | 151714   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 11.2     |
# |    n_updates        | 37903    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 206      |
# |    ep_rew_mean      | -59      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 28       |
# |    time_elapsed     | 5279     |
# |    total_timesteps  | 152087   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000366 |
# |    n_updates        | 37996    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 208      |
# |    ep_rew_mean      | -58.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 28       |
# |    time_elapsed     | 5301     |
# |    total_timesteps  | 152665   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000333 |
# |    n_updates        | 38141    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 230      |
# |    ep_rew_mean      | -54.2    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 28       |
# |    time_elapsed     | 5386     |
# |    total_timesteps  | 155144   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000418 |
# |    n_updates        | 38760    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | -54.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 28       |
# |    time_elapsed     | 5391     |
# |    total_timesteps  | 155248   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00114  |
# |    n_updates        | 38786    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 229      |
# |    ep_rew_mean      | -54.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 28       |
# |    time_elapsed     | 5426     |
# |    total_timesteps  | 156218   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000488 |
# |    n_updates        | 39029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 258      |
# |    ep_rew_mean      | -48.5    |
# |    exploration_rate | 0.05     |
# ...
# |    time_elapsed     | 31332    |
# |    total_timesteps  | 852701   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.34     |
# |    n_updates        | 213150   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 665      |
# |    ep_rew_mean      | 32.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4848     |
# |    fps              | 27       |
# |    time_elapsed     | 31779    |
# |    total_timesteps  | 866040   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02     |
# |    n_updates        | 216484   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 689      |
# |    ep_rew_mean      | 37.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4852     |
# |    fps              | 27       |
# |    time_elapsed     | 31869    |
# |    total_timesteps  | 868686   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.36     |
# |    n_updates        | 217146   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 803      |
# |    ep_rew_mean      | 60.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4856     |
# |    fps              | 27       |
# |    time_elapsed     | 32268    |
# |    total_timesteps  | 880562   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.77     |
# |    n_updates        | 220115   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 908      |
# |    ep_rew_mean      | 81.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4860     |
# |    fps              | 27       |
# |    time_elapsed     | 32641    |
# |    total_timesteps  | 891687   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.3      |
# |    n_updates        | 222896   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.09e+03 |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4864     |
# |    fps              | 27       |
# |    time_elapsed     | 33263    |
# |    total_timesteps  | 910285   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.82     |
# |    n_updates        | 227546   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.16e+03 |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4868     |
# |    fps              | 27       |
# |    time_elapsed     | 33557    |
# |    total_timesteps  | 919038   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.04     |
# |    n_updates        | 229734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.18e+03 |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4872     |
# |    fps              | 27       |
# |    time_elapsed     | 33617    |
# |    total_timesteps  | 920767   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.71     |
# |    n_updates        | 230166   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.22e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4876     |
# |    fps              | 27       |
# |    time_elapsed     | 33788    |
# |    total_timesteps  | 925807   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.25     |
# |    n_updates        | 231426   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.21e+03 |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4880     |
# |    fps              | 27       |
# |    time_elapsed     | 33802    |
# |    total_timesteps  | 926172   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.901    |
# |    n_updates        | 231517   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.28e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4884     |
# |    fps              | 27       |
# |    time_elapsed     | 34085    |
# |    total_timesteps  | 934595   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.917    |
# |    n_updates        | 233623   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.33e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4888     |
# |    fps              | 27       |
# |    time_elapsed     | 34318    |
# |    total_timesteps  | 941501   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.17     |
# |    n_updates        | 235350   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.46e+03 |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4892     |
# |    fps              | 27       |
# |    time_elapsed     | 34807    |
# |    total_timesteps  | 956085   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.725    |
# |    n_updates        | 238996   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.49e+03 |
# |    ep_rew_mean      | 197      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4896     |
# |    fps              | 27       |
# |    time_elapsed     | 34923    |
# |    total_timesteps  | 959504   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.737    |
# |    n_updates        | 239850   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.51e+03 |
# |    ep_rew_mean      | 202      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4900     |
# |    fps              | 27       |
# |    time_elapsed     | 35094    |
# |    total_timesteps  | 964553   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.34     |
# |    n_updates        | 241113   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.5e+03  |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4904     |
# |    fps              | 27       |
# |    time_elapsed     | 35121    |
# |    total_timesteps  | 965296   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.345    |
# |    n_updates        | 241298   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.51e+03 |
# |    ep_rew_mean      | 201      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4908     |
# |    fps              | 27       |
# |    time_elapsed     | 35197    |
# |    total_timesteps  | 967505   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.738    |
# |    n_updates        | 241851   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.5e+03  |
# |    ep_rew_mean      | 200      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4912     |
# |    fps              | 27       |
# |    time_elapsed     | 35204    |
# |    total_timesteps  | 967655   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.685    |
# |    n_updates        | 241888   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.51e+03 |
# |    ep_rew_mean      | 203      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4916     |
# |    fps              | 27       |
# |    time_elapsed     | 35298    |
# |    total_timesteps  | 970399   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.808    |
# |    n_updates        | 242574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.52e+03 |
# |    ep_rew_mean      | 203      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4920     |
# |    fps              | 27       |
# |    time_elapsed     | 35375    |
# |    total_timesteps  | 972623   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.62     |
# |    n_updates        | 243130   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.5e+03  |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4924     |
# |    fps              | 27       |
# |    time_elapsed     | 35406    |
# |    total_timesteps  | 973484   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.88     |
# |    n_updates        | 243345   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.51e+03 |
# |    ep_rew_mean      | 201      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4928     |
# |    fps              | 27       |
# |    time_elapsed     | 35508    |
# |    total_timesteps  | 976466   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.293    |
# |    n_updates        | 244091   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.49e+03 |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4932     |
# |    fps              | 27       |
# |    time_elapsed     | 35522    |
# |    total_timesteps  | 976837   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.865    |
# |    n_updates        | 244184   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.48e+03 |
# |    ep_rew_mean      | 195      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4936     |
# |    fps              | 27       |
# |    time_elapsed     | 35616    |
# |    total_timesteps  | 979587   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.04     |
# |    n_updates        | 244871   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.46e+03 |
# |    ep_rew_mean      | 191      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4940     |
# |    fps              | 27       |
# |    time_elapsed     | 35692    |
# |    total_timesteps  | 981770   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.271    |
# |    n_updates        | 245417   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.31e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4944     |
# |    fps              | 27       |
# |    time_elapsed     | 35773    |
# |    total_timesteps  | 984154   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.682    |
# |    n_updates        | 246013   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.2e+03  |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4948     |
# |    fps              | 27       |
# |    time_elapsed     | 35824    |
# |    total_timesteps  | 985601   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.316    |
# |    n_updates        | 246375   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.2e+03  |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4952     |
# |    fps              | 27       |
# |    time_elapsed     | 35916    |
# |    total_timesteps  | 988283   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.921    |
# |    n_updates        | 247045   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.1e+03  |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4956     |
# |    fps              | 27       |
# |    time_elapsed     | 36002    |
# |    total_timesteps  | 990787   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.619    |
# |    n_updates        | 247671   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.02e+03 |
# |    ep_rew_mean      | 104      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4960     |
# |    fps              | 27       |
# |    time_elapsed     | 36108    |
# |    total_timesteps  | 993899   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.101    |
# |    n_updates        | 248449   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 864      |
# |    ep_rew_mean      | 72.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4964     |
# |    fps              | 27       |
# |    time_elapsed     | 36204    |
# |    total_timesteps  | 996699   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.557    |
# |    n_updates        | 249149   |
# ----------------------------------

# %%
model_load = DQN.load('dqn_geometry_dash', env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
obs, info = env.reset()

# Test the agent for a fixed number of steps
for _ in range(1000):  # Adjust the number of steps
    action, _states = model.predict(obs, deterministic=True)  # Get action from the model
    obs, reward, done, truncated, info = env.step(action)
    print(f"Action: {action}, Reward: {reward}, Done: {done}")
    
    # Reset the environment if done
    if done or truncated:
        obs, info = env.reset()
# Out:
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: -100, Done: True
# Action: 0, Reward: -100, Done: True
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: -100, Done: True
# Action: 0, Reward: -100, Done: True
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 1, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
# Action: 0, Reward: 0.2, Done: False
